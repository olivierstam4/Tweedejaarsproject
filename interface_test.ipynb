# %% [markdown]
# Change the file path to your file and the data you want to access.

# %%
file_path = 'Data/Nieuw/2.P01.xlsx'
DATE = '2024-06-12'

# %% [markdown]
# Now just run the code below.

# %%
from new_useful_functions import import_file, remove_before, remove_zeros, make_bins, make_equal_bins, peaks_for_specific_timeframe, show_valid_peaks, make_sessions, calculate_session_averages, add_session_averages, surrounded_by_low_counts, preprocess, summary
from scipy.signal import find_peaks
import pandas as pd

# %% [markdown]
# Import your raw data file.

# %%
file = preprocess(file_path)

# %%
file
# Out:
#                    Date  Count
# 24  2024-06-12 08:10:15    0.0
# 25  2024-06-12 08:16:40    3.0
# 26  2024-06-12 08:21:40  153.0
# 27  2024-06-12 08:26:40    0.0
# 28  2024-06-12 08:31:40    0.0
# ..                  ...    ...
# 200 2024-06-12 23:41:52    0.0
# 201 2024-06-12 23:46:52    0.0
# 202 2024-06-12 23:47:50    2.0
# 203 2024-06-12 23:52:50   14.0
# 204 2024-06-12 23:57:50    0.0
#
# [181 rows x 2 columns]

# %%
X, y, z= make_sessions(file, DATE, 5, 1)

# %%
bla = show_valid_peaks(file, DATE, 1, 1, 0 )

# %%
summary(z)
# Out:
# Session 0 took 10 minute(s), with an average of 1.50 movements, resulting in an estimated occupancy of 0.30
#
# Session 1 took 20 minute(s), with an average of 38.25 movements, resulting in an estimated occupancy of 7.65
#
# Session 2 took 35 minute(s), with an average of 6.57 movements, resulting in an estimated occupancy of 1.31
#
# Session 3 took 1 hour(s) and 0 minute(s), with an average of 5.36 movements, resulting in an estimated occupancy of 0.98
#
# Session 4 took 1 hour(s) and 5 minute(s), with an average of 5.77 movements, resulting in an estimated occupancy of 1.15
#
# Session 5 took 5 hour(s) and 5 minute(s), with an average of 215.95 movements, resulting in an estimated occupancy of 43.19
#
# Session 6 took 1 hour(s) and 40 minute(s), with an average of 165.37 movements, resulting in an estimated occupancy of 31.42
#
# Session 7 took 45 minute(s), with an average of 62.78 movements, resulting in an estimated occupancy of 12.56
#
# Session 8 took 25 minute(s), with an average of 19.20 movements, resulting in an estimated occupancy of 3.84
#
# Session 9 took 3 hour(s) and 50 minute(s), with an average of 238.26 movements, resulting in an estimated occupancy of 47.65
#
# Session 10 took 10 minute(s), with an average of 7.00 movements, resulting in an estimated occupancy of 1.40
