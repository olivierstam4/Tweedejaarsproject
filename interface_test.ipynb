# %% [markdown]
# Change the file path to your file and the data you want to access.

# %%
file_path = 'Data/Nieuw/2.P01.xlsx'
DATE = '2024-06-12'

# %% [markdown]
# Now just run the code below.

# %%
from model import *

# %%
file = preprocess(file_path)
img, stats = predict_occupancy_session(file, DATE)
display(Image(data=img))

# %%
summary(stats)
# Out:
# Session 1 took 4 hour(s) and 45 minute(s), with an average of 228 movements per 5 minutes, resulting in an estimated occupancy of 4 people
#
# Session 2 took 45 minute(s), with an average of 204 movements per 5 minutes, resulting in an estimated occupancy of 3 people
#
# Session 3 took 50 minute(s), with an average of 151 movements per 5 minutes, resulting in an estimated occupancy of 2 people
#
# Session 4 took 3 hour(s) and 15 minute(s), with an average of 254 movements per 5 minutes, resulting in an estimated occupancy of 4 people
